# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 1
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
cita = '¿Por qué esta magnífica tecnología científica,\n \tque ahorra trabajo y nos hace la vida mas fácil,\n \t\tnos aporta tan poca felicidad?\n \t\t\tLa respuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.\n "Albert Einstein"'
print(cita)
# Out:
# ¿Por qué esta magnífica tecnología científica,
#  	que ahorra trabajo y nos hace la vida mas fácil,
#  		nos aporta tan poca felicidad?
#  			La respuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.
#  "Albert Einstein"

# %% [markdown]
# ## Ejercicio 2
# 1. Escribe el nombre de la calle de tu domicilio
# 2. Escribe el numero de la calle en otra
# 3. Población en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Crea una quinta variable que concatene todas ellas
# 6. Imprimela por pantalla

# %%
calle_domicilio = "Calle Yatova"
numero_calle = 2
poblacion = "Valencia"
codigo_postal = 46014

total = calle_domicilio + " " + str(numero_calle) + " " + poblacion + " " + str(codigo_postal) 
print(total)
# Out:
# Calle Yatova 2 Valencia 46014

# %% [markdown]
# ## Ejercicio 3
# Replica el output del ejercicio dos, pero está vez sin usar una variable intermedia que concatene todas las demas. Realiza este ejercicio en una línea, con un  único `print`

# %%
print(calle_domicilio , numero_calle , poblacion , codigo_postal)
# Out:
# Calle Yatova 2 Valencia 46014

# %% [markdown]
# ## Ejercicio 4
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. exec = True
# 6. import = 40
# 7. 81mi_variable = "Agua"
# 8. mi_variable10 = 6

# %%
mi_variable = "Economía"
print(mi_variable)

otra_var = "Ejercicio"
print(otra_var)

mi_variab1e = "Alpha"
print(mi_variab1e)

exec = True

import 40

81mi_variable
# Out:
#   Cell In[9], line 12
#     import 40
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# 1. Está bien escrita, sintaxis correcta
# 2. String requiere cerrar con "
# 3. Las variables no se escriben con espacio, _ preferiblemente
# 4. Bien escrita, variable True empezando en mayúscula
# 5. La consulta de import no es una sintaxis correcta
# 6. No existe la librería 40
# 7.
# 8.

# %% [markdown]
# ## Ejercicio 5
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = (C × 9 / 5) + 32

# %%
# Out:
# El equivalente en grados Fahrenheit es 42.8

# %% [markdown]
# ## Ejercicio 6
# Comenta en la medida de lo posible el Ejercicio 5. Será suficiente con poner al menos un comentario de línea, y otro multilínea

# %%
# Out:
# El equivalente en grados Fahrenheit es 41.0
